-- %%
--- Checking the entire data
SELECT * 
FROM `workspace`.`default`.`car_sales`;


--- First & Last date of data collection
SELECT CAST(MIN(year) AS STRING) AS start_date,
       CAST(MAX(year) AS STRING) AS end_date
FROM `workspace`.`default`.`car_sales`;

SELECT DISTINCT(year)
FROM `workspace`.`default`.`car_sales`;
